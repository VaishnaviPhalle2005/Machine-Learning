# %% [markdown]
# # **Assignment No - 10**
#
# ---
#
# **Name**- Vaishnavi Krishnat Phalle.
# **Roll No**-EN23107096.
# **Class**-AIDS(B).
# **Batch**- A.
#
# ---
#
# **Title** -
# Solve the Taxi problem using reinforcement learning, where an agent acts as a taxi driver to pick up and drop off passengers efficiently.

# %%
# !apt-get install xll-utils > /dev/null 2>&1
# !pip install pyglet > /dev/null 2>&1
# !apt-get install -y Xvfb python-opengl > /dev/null 2>&1

# %%
import gym
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
env = gym.make('Taxi-v3').env
# Out:
# /usr/local/lib/python3.12/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.12/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
env.reset()
# Out:
# 182

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display as ipythondisplay

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %%
# !apt-get install -y xvfb
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.15).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (2.6.1)

# %% [markdown]
# **Rendering**

# %%
env.reset()
prev_screen = env.render(mode= 'rgb_array')
plt.imshow(prev_screen)

for i in range(100):

  action = env.action_space.sample()
  new_state, obs, done, info = env.step(action)
  new_screen = env.render(mode= 'rgb_array')
  plt.imshow(new_screen)
  ipythondisplay.clear_output(wait=True)
  ipythondisplay.display(plt.gcf())

  if done:
    break

ipythondisplay.clear_output(wait=True)
env.close()

ipythondisplay.clear_output(wait=True)
env.close()

# %%
print(f'Action Space {env.action_space}')
print(f'State Space {env.observation_space}')
state= env.encode(3,1,2,0)
print(f'State: {state}')
env.s = state
# Out:
# Action Space Discrete(6)
# State Space Discrete(500)
# State: 328

# %%
env.P[328]
# Out:
# {0: [(1.0, 428, -1, False)],
#  1: [(1.0, 228, -1, False)],
#  2: [(1.0, 348, -1, False)],
#  3: [(1.0, 328, -1, False)],
#  4: [(1.0, 328, -10, False)],
#  5: [(1.0, 328, -10, False)]}

# %% [markdown]
# **Exploration**

# %%
env.S = 328
epochs = 0
penalties, rewards = 0,0
frames = []
done = False

while not done:
  action = env.action_space.sample()
  state, reward, done, info = env.step(action)

  if reward == -10:
    penalties += 1

  frames.append({
      'frame': env.render(mode='ansi'),
      'state': state,
      'action': action,
      'reward': reward
      }
  )

  epochs +=1

  print(f'Timesteps taken: {epochs}')
  print(f'Penalties incurred: {penalties}')
# Out:
# Timesteps taken: 1
# Penalties incurred: 1
# Timesteps taken: 2
# Penalties incurred: 2
# Timesteps taken: 3
# Penalties incurred: 2
# Timesteps taken: 4
# Penalties incurred: 3
# Timesteps taken: 5
# Penalties incurred: 3
# Timesteps taken: 6
# Penalties incurred: 3
# Timesteps taken: 7
# Penalties incurred: 4
# Timesteps taken: 8
# Penalties incurred: 4
# Timesteps taken: 9
# Penalties incurred: 5
# Timesteps taken: 10
# Penalties incurred: 6
# Timesteps taken: 11
# Penalties incurred: 7
# Timesteps taken: 12
# Penalties incurred: 8
# Timesteps taken: 13
# Penalties incurred: 8
# Timesteps taken: 14
# Penalties incurred: 9
# Timesteps taken: 15
# Penalties incurred: 10
# Timesteps taken: 16
# Penalties incurred: 11
# Timesteps taken: 17
# Penalties incurred: 11
# Timesteps taken: 18
# Penalties incurred: 11
# Timesteps taken: 19
# Penalties incurred: 11
# Timesteps taken: 20
# Penalties incurred: 11
# Timesteps taken: 21
# Penalties incurred: 11
# Timesteps taken: 22
# Penalties incurred: 12
# Timesteps taken: 23
# Penalties incurred: 13
# Timesteps taken: 24
# Penalties incurred: 13
# Timesteps taken: 25
# Penalties incurred: 13
# Timesteps taken: 26
# Penalties incurred: 13
# Timesteps taken: 27
# Penalties incurred: 14
# Timesteps taken: 28
# Penalties incurred: 14
# Timesteps taken: 29
# Penalties incurred: 15
# Timesteps taken: 30
# Penalties incurred: 15
# Timesteps taken: 31
# Penalties incurred: 15
# Timesteps taken: 32
# Penalties incurred: 15
# Timesteps taken: 33
# Penalties incurred: 15
# Timesteps taken: 34
# Penalties incurred: 15
# Timesteps taken: 35
# Penalties incurred: 15
# Timesteps taken: 36
# Penalties incurred: 16
# Timesteps taken: 37
# Penalties incurred: 16
# Timesteps taken: 38
# Penalties incurred: 17
# Timesteps taken: 39
# Penalties incurred: 17
# Timesteps taken: 40
# Penalties incurred: 18
# Timesteps taken: 41
# Penalties incurred: 19
# Timesteps taken: 42
# Penalties incurred: 19
# Timesteps taken: 43
# Penalties incurred: 19
# Timesteps taken: 44
# Penalties incurred: 20
# Timesteps taken: 45
# Penalties incurred: 21
# Timesteps taken: 46
# Penalties incurred: 21
# Timesteps taken: 47
# Penalties incurred: 21
# Timesteps taken: 48
# Penalties incurred: 21
# Timesteps taken: 49
# Penalties incurred: 21
# Timesteps taken: 50
# Penalties incurred: 21
# Timesteps taken: 51
# Penalties incurred: 21
# Timesteps taken: 52
# Penalties incurred: 22
# Timesteps taken: 53
# Penalties incurred: 22
# Timesteps taken: 54
# Penalties incurred: 22
# Timesteps taken: 55
# Penalties incurred: 22
# Timesteps taken: 56
# Penalties incurred: 22
# Timesteps taken: 57
# Penalties incurred: 22
# Timesteps taken: 58
# Penalties incurred: 23
# Timesteps taken: 59
# Penalties incurred: 24
# Timesteps taken: 60
# Penalties incurred: 24
# Timesteps taken: 61
# Penalties incurred: 24
# Timesteps taken: 62
# Penalties incurred: 25
# Timesteps taken: 63
# Penalties incurred: 25
# Timesteps taken: 64
# Penalties incurred: 25
# Timesteps taken: 65
# Penalties incurred: 25
# Timesteps taken: 66
# Penalties incurred: 25
# Timesteps taken: 67
# Penalties incurred: 25
# Timesteps taken: 68
# Penalties incurred: 25
# Timesteps taken: 69
# Penalties incurred: 26
# Timesteps taken: 70
# Penalties incurred: 26
# Timesteps taken: 71
# Penalties incurred: 26
# Timesteps taken: 72
# Penalties incurred: 26
# Timesteps taken: 73
# Penalties incurred: 26
# Timesteps taken: 74
# Penalties incurred: 27
# Timesteps taken: 75
# Penalties incurred: 27
# Timesteps taken: 76
# Penalties incurred: 27
# Timesteps taken: 77
# Penalties incurred: 27
# Timesteps taken: 78
# Penalties incurred: 28
# Timesteps taken: 79
# Penalties incurred: 28
# Timesteps taken: 80
# Penalties incurred: 29
# Timesteps taken: 81
# Penalties incurred: 30
# Timesteps taken: 82
# Penalties incurred: 30
# Timesteps taken: 83
# Penalties incurred: 30
# Timesteps taken: 84
# Penalties incurred: 30
# Timesteps taken: 85
# Penalties incurred: 31
# Timesteps taken: 86
# Penalties incurred: 32
# Timesteps taken: 87
# Penalties incurred: 33
# Timesteps taken: 88
# Penalties incurred: 33
# Timesteps taken: 89
# Penalties incurred: 33
# Timesteps taken: 90
# Penalties incurred: 34
# Timesteps taken: 91
# Penalties incurred: 34
# Timesteps taken: 92
# Penalties incurred: 34
# Timesteps taken: 93
# Penalties incurred: 35
# Timesteps taken: 94
# Penalties incurred: 36
# Timesteps taken: 95
# Penalties incurred: 36
# Timesteps taken: 96
# Penalties incurred: 36
# Timesteps taken: 97
# Penalties incurred: 36
# Timesteps taken: 98
# Penalties incurred: 36
# Timesteps taken: 99
# Penalties incurred: 36
# Timesteps taken: 100
# Penalties incurred: 36
# Timesteps taken: 101
# Penalties incurred: 36
# Timesteps taken: 102
# Penalties incurred: 36
# Timesteps taken: 103
# Penalties incurred: 36
# Timesteps taken: 104
# Penalties incurred: 36
# Timesteps taken: 105
# Penalties incurred: 36
# Timesteps taken: 106
# Penalties incurred: 36
# Timesteps taken: 107
# Penalties incurred: 37
# Timesteps taken: 108
# Penalties incurred: 38
# Timesteps taken: 109
# Penalties incurred: 38
# Timesteps taken: 110
# Penalties incurred: 39
# Timesteps taken: 111
# Penalties incurred: 40
# Timesteps taken: 112
# Penalties incurred: 41
# Timesteps taken: 113
# Penalties incurred: 41
# Timesteps taken: 114
# Penalties incurred: 41
# Timesteps taken: 115
# Penalties incurred: 41
# Timesteps taken: 116
# Penalties incurred: 42
# Timesteps taken: 117
# Penalties incurred: 42
# Timesteps taken: 118
# Penalties incurred: 42
# Timesteps taken: 119
# Penalties incurred: 43
# Timesteps taken: 120
# Penalties incurred: 44
# Timesteps taken: 121
# Penalties incurred: 44
# Timesteps taken: 122
# Penalties incurred: 44
# Timesteps taken: 123
# Penalties incurred: 44
# Timesteps taken: 124
# Penalties incurred: 45
# Timesteps taken: 125
# Penalties incurred: 46
# Timesteps taken: 126
# Penalties incurred: 46
# Timesteps taken: 127
# Penalties incurred: 46
# Timesteps taken: 128
# Penalties incurred: 47
# Timesteps taken: 129
# Penalties incurred: 47
# Timesteps taken: 130
# Penalties incurred: 47
# Timesteps taken: 131
# Penalties incurred: 48
# Timesteps taken: 132
# Penalties incurred: 48
# Timesteps taken: 133
# Penalties incurred: 49
# Timesteps taken: 134
# Penalties incurred: 49
# Timesteps taken: 135
# Penalties incurred: 50
# Timesteps taken: 136
# Penalties incurred: 50
# Timesteps taken: 137
# Penalties incurred: 50
# Timesteps taken: 138
# Penalties incurred: 50
# Timesteps taken: 139
# Penalties incurred: 50
# Timesteps taken: 140
# Penalties incurred: 50
# Timesteps taken: 141
# Penalties incurred: 51
# Timesteps taken: 142
# Penalties incurred: 52
# Timesteps taken: 143
# Penalties incurred: 52
# Timesteps taken: 144
# Penalties incurred: 52
# Timesteps taken: 145
# Penalties incurred: 52
# Timesteps taken: 146
# Penalties incurred: 52
# Timesteps taken: 147
# Penalties incurred: 52
# Timesteps taken: 148
# Penalties incurred: 53
# Timesteps taken: 149
# Penalties incurred: 53
# Timesteps taken: 150
# Penalties incurred: 54
# Timesteps taken: 151
# Penalties incurred: 54
# Timesteps taken: 152
# Penalties incurred: 54
# Timesteps taken: 153
# Penalties incurred: 54
# Timesteps taken: 154
# Penalties incurred: 55
# Timesteps taken: 155
# Penalties incurred: 55
# Timesteps taken: 156
# Penalties incurred: 55
# Timesteps taken: 157
# Penalties incurred: 56
# Timesteps taken: 158
# Penalties incurred: 56
# Timesteps taken: 159
# Penalties incurred: 56
# Timesteps taken: 160
# Penalties incurred: 57
# Timesteps taken: 161
# Penalties incurred: 58
# Timesteps taken: 162
# Penalties incurred: 58
# Timesteps taken: 163
# Penalties incurred: 58
# Timesteps taken: 164
# Penalties incurred: 58
# Timesteps taken: 165
# Penalties incurred: 58
# Timesteps taken: 166
# Penalties incurred: 58
# Timesteps taken: 167
# Penalties incurred: 58
# Timesteps taken: 168
# Penalties incurred: 58
# Timesteps taken: 169
# Penalties incurred: 59
# Timesteps taken: 170
# Penalties incurred: 59
# Timesteps taken: 171
# Penalties incurred: 59
# Timesteps taken: 172
# Penalties incurred: 59
# Timesteps taken: 173
# Penalties incurred: 59
# Timesteps taken: 174
# Penalties incurred: 59
# Timesteps taken: 175
# Penalties incurred: 59
# Timesteps taken: 176
# Penalties incurred: 60
# Timesteps taken: 177
# Penalties incurred: 60
# Timesteps taken: 178
# Penalties incurred: 61
# Timesteps taken: 179
# Penalties incurred: 62
# Timesteps taken: 180
# Penalties incurred: 62
# Timesteps taken: 181
# Penalties incurred: 62
# Timesteps taken: 182
# Penalties incurred: 62
# Timesteps taken: 183
# Penalties incurred: 62
# Timesteps taken: 184
# Penalties incurred: 63
# Timesteps taken: 185
# Penalties incurred: 64
# Timesteps taken: 186
# Penalties incurred: 65
# Timesteps taken: 187
# Penalties incurred: 65
# Timesteps taken: 188
# Penalties incurred: 65
# Timesteps taken: 189
# Penalties incurred: 65
# Timesteps taken: 190
# Penalties incurred: 65
# Timesteps taken: 191
# Penalties incurred: 65
# Timesteps taken: 192
# Penalties incurred: 65
# Timesteps taken: 193
# Penalties incurred: 65
# Timesteps taken: 194
# Penalties incurred: 65
# Timesteps taken: 195
# Penalties incurred: 65
# Timesteps taken: 196
# Penalties incurred: 66
# Timesteps taken: 197
# Penalties incurred: 66
# Timesteps taken: 198
# Penalties incurred: 66
# Timesteps taken: 199
# Penalties incurred: 67
# Timesteps taken: 200
# Penalties incurred: 67
# Timesteps taken: 201
# Penalties incurred: 67
# Timesteps taken: 202
# Penalties incurred: 68
# Timesteps taken: 203
# Penalties incurred: 68
# Timesteps taken: 204
# Penalties incurred: 68
# Timesteps taken: 205
# Penalties incurred: 68
# Timesteps taken: 206
# Penalties incurred: 68
# Timesteps taken: 207
# Penalties incurred: 69
# Timesteps taken: 208
# Penalties incurred: 69
# Timesteps taken: 209
# Penalties incurred: 69
# Timesteps taken: 210
# Penalties incurred: 69
# Timesteps taken: 211
# Penalties incurred: 70
# Timesteps taken: 212
# Penalties incurred: 71
# Timesteps taken: 213
# Penalties incurred: 71
# Timesteps taken: 214
# Penalties incurred: 71
# Timesteps taken: 215
# Penalties incurred: 72
# Timesteps taken: 216
# Penalties incurred: 72
# Timesteps taken: 217
# Penalties incurred: 72
# Timesteps taken: 218
# Penalties incurred: 72
# Timesteps taken: 219
# Penalties incurred: 72
# Timesteps taken: 220
# Penalties incurred: 72
# Timesteps taken: 221
# Penalties incurred: 73
# Timesteps taken: 222
# Penalties incurred: 73
# Timesteps taken: 223
# Penalties incurred: 73
# Timesteps taken: 224
# Penalties incurred: 73
# Timesteps taken: 225
# Penalties incurred: 74
# Timesteps taken: 226
# Penalties incurred: 75
# Timesteps taken: 227
# Penalties incurred: 75
# Timesteps taken: 228
# Penalties incurred: 75
# Timesteps taken: 229
# Penalties incurred: 75
# Timesteps taken: 230
# Penalties incurred: 76
# Timesteps taken: 231
# Penalties incurred: 76
# Timesteps taken: 232
# Penalties incurred: 76
# Timesteps taken: 233
# Penalties incurred: 77
# Timesteps taken: 234
# Penalties incurred: 77
# Timesteps taken: 235
# Penalties incurred: 78
# Timesteps taken: 236
# Penalties incurred: 78
# Timesteps taken: 237
# Penalties incurred: 78
# Timesteps taken: 238
# Penalties incurred: 78
# Timesteps taken: 239
# Penalties incurred: 78
# Timesteps taken: 240
# Penalties incurred: 78
# Timesteps taken: 241
# Penalties incurred: 78
# Timesteps taken: 242
# Penalties incurred: 78
# Timesteps taken: 243
# Penalties incurred: 79
# Timesteps taken: 244
# Penalties incurred: 79
# Timesteps taken: 245
# Penalties incurred: 79
# Timesteps taken: 246
# Penalties incurred: 80
# Timesteps taken: 247
# Penalties incurred: 80
# Timesteps taken: 248
# Penalties incurred: 81
# Timesteps taken: 249
# Penalties incurred: 81
# Timesteps taken: 250
# Penalties incurred: 82
# Timesteps taken: 251
# Penalties incurred: 82
# Timesteps taken: 252
# Penalties incurred: 82
# Timesteps taken: 253
# Penalties incurred: 82
# Timesteps taken: 254
# Penalties incurred: 82
# Timesteps taken: 255
# Penalties incurred: 82
# Timesteps taken: 256
# Penalties incurred: 83
# Timesteps taken: 257
# Penalties incurred: 83
# Timesteps taken: 258
# Penalties incurred: 83
# Timesteps taken: 259
# Penalties incurred: 83
# Timesteps taken: 260
# Penalties incurred: 83
# Timesteps taken: 261
# Penalties incurred: 83
# Timesteps taken: 262
# Penalties incurred: 83
# Timesteps taken: 263
# Penalties incurred: 84
# Timesteps taken: 264
# Penalties incurred: 84
# Timesteps taken: 265
# Penalties incurred: 85
# Timesteps taken: 266
# Penalties incurred: 85
# Timesteps taken: 267
# Penalties incurred: 85
# Timesteps taken: 268
# Penalties incurred: 86
# Timesteps taken: 269
# Penalties incurred: 87
# Timesteps taken: 270
# Penalties incurred: 87
# Timesteps taken: 271
# Penalties incurred: 87
# Timesteps taken: 272
# Penalties incurred: 87
# Timesteps taken: 273
# Penalties incurred: 87
# Timesteps taken: 274
# Penalties incurred: 87
# Timesteps taken: 275
# Penalties incurred: 87
# Timesteps taken: 276
# Penalties incurred: 87
# Timesteps taken: 277
# Penalties incurred: 88
# Timesteps taken: 278
# Penalties incurred: 89
# Timesteps taken: 279
# Penalties incurred: 89
# Timesteps taken: 280
# Penalties incurred: 90
# Timesteps taken: 281
# Penalties incurred: 90
# Timesteps taken: 282
# Penalties incurred: 91
# Timesteps taken: 283
# Penalties incurred: 91
# Timesteps taken: 284
# Penalties incurred: 91
# Timesteps taken: 285
# Penalties incurred: 91
# Timesteps taken: 286
# Penalties incurred: 91
# Timesteps taken: 287
# Penalties incurred: 91
# Timesteps taken: 288
# Penalties incurred: 91
# Timesteps taken: 289
# Penalties incurred: 91
# Timesteps taken: 290
# Penalties incurred: 91
# Timesteps taken: 291
# Penalties incurred: 92
# Timesteps taken: 292
# Penalties incurred: 92
# Timesteps taken: 293
# Penalties incurred: 92
# Timesteps taken: 294
# Penalties incurred: 92
# Timesteps taken: 295
# Penalties incurred: 92
# Timesteps taken: 296
# Penalties incurred: 92
# Timesteps taken: 297
# Penalties incurred: 92
# Timesteps taken: 298
# Penalties incurred: 93
# Timesteps taken: 299
# Penalties incurred: 94
# Timesteps taken: 300
# Penalties incurred: 94
# Timesteps taken: 301
# Penalties incurred: 94
# Timesteps taken: 302
# Penalties incurred: 95
# Timesteps taken: 303
# Penalties incurred: 95
# Timesteps taken: 304
# Penalties incurred: 95
# Timesteps taken: 305
# Penalties incurred: 95
# Timesteps taken: 306
# Penalties incurred: 95
# Timesteps taken: 307
# Penalties incurred: 95
# Timesteps taken: 308
# Penalties incurred: 96
# Timesteps taken: 309
# Penalties incurred: 97
# Timesteps taken: 310
# Penalties incurred: 97
# Timesteps taken: 311
# Penalties incurred: 98
# Timesteps taken: 312
# Penalties incurred: 98
# Timesteps taken: 313
# Penalties incurred: 98
# Timesteps taken: 314
# Penalties incurred: 98
# Timesteps taken: 315
# Penalties incurred: 98
# Timesteps taken: 316
# Penalties incurred: 98
# Timesteps taken: 317
# Penalties incurred: 99
# Timesteps taken: 318
# Penalties incurred: 100
# Timesteps taken: 319
# Penalties incurred: 100
# Timesteps taken: 320
# Penalties incurred: 100
# Timesteps taken: 321
# Penalties incurred: 100
# Timesteps taken: 322
# Penalties incurred: 100
# Timesteps taken: 323
# Penalties incurred: 100
# Timesteps taken: 324
# Penalties incurred: 101
# Timesteps taken: 325
# Penalties incurred: 101
# Timesteps taken: 326
# Penalties incurred: 101
# Timesteps taken: 327
# Penalties incurred: 102
# Timesteps taken: 328
# Penalties incurred: 103
# Timesteps taken: 329
# Penalties incurred: 103
# Timesteps taken: 330
# Penalties incurred: 103
# Timesteps taken: 331
# Penalties incurred: 103

# %% [markdown]
# **Visualization of Exploration**

# %%
from IPython.display import clear_output
from time import sleep

def print_frames(frames):
  for i, frame in enumerate(frames):
    clear_output(wait=True)
    print(frame['frame'])
    print(f'Timestep: {i + 1}')
    print(f'State: {frame["state"]}')
    print(f'Action: {frame["action"]}')
    print(f'Reward: {frame["reward"]}')
    sleep(.1)
print_frames(frames)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Timestep: 331
# State: 85
# Action: 5
# Reward: 20

# %%
state_size = env.observation_space.n
action_size = env.action_space.n
Q = np.zeros([state_size, action_size])

# %% [markdown]
# **Traing the agent using Exploration and Exploitation.**

# %%
# %%time
import random
from IPython.display import clear_output
# Out:
# CPU times: user 16 µs, sys: 0 ns, total: 16 µs
# Wall time: 20.3 µs

# %%
alpha = 0.1
gamma = 0.6
epsilon = 0.1

all_epochs = []
all_penalties = []

# %%
for i in range(i, 100001):
  state = env.reset()
  epochs, penalties, reward = 0, 1, 0

  done = False
  while not done:

    if random.uniform(0, 1) < epsilon:
      action = env.action_space.sample()
    else:
      action = np.argmax(Q[state])
    new_state, reward, done, info = env.step(action)
    old_value = Q[state,action]
    next_max = np.max(Q[new_state])
    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
    Q[state, action] = new_value

    if reward == -10:
      penalties += 1

    state = new_state
    epochs += 1

  if i % 100 ==0:
    clear_output(wait=True)
    print(f'Episode: {i}')

print('Training completed. \n')
# Out:
# Episode: 100000
# Training completed.

# %%
Q[328]
# Out:
# array([ -2.40390416,  -2.27325184,  -2.40950991,  -2.35752573,
#        -10.86822935, -10.93302827])

# %% [markdown]
# **Testing the agent**

# %%
total_epochs, total_penalties = 1, 1
episodes = 100

for _ in range(episodes):
  state = env.reset()
  epochs, penalties, reward = 0, 1, 0

  done = False
  while not done:
    action = np.argmax(Q[state])
    state, reward, done, info = env.step(action)

    if reward == -10:
      penalties += 1
      epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f'Results after {episodes} episodes: ')
print(f'Average timesteps per episode: {total_epochs/episodes}')
print(f'Average penalties per episode: {total_penalties/episodes}')
# Out:
# Results after 100 episodes:
# Average timesteps per episode: 0.01
# Average penalties per episode: 12.67

# %% [markdown]
# **Watching the taxi drop-off**

# %%
env.reset()
prev_screen = env.render(mode='rgb_array')
plt.imshow(prev_screen)

for _ in range(episodes):
  action = env.action_space.sample()
  state, penalty, done, info = env.step(action)
  screen = env.render(mode='rgb_array')

  plt.imshow(screen)
  ipythondisplay.clear_output(wait=True)
  ipythondisplay.display(plt.gcf())

  if done:
    break

ipythondisplay.clear_output(wait=True)
env.close()

ipythondisplay.clear_output(wait=True)
env.close()
